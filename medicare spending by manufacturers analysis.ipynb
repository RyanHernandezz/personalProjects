# %%
import pandas as pd
import numpy as np
import seaborn as sns
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
#loading the data
df = pd.read_csv('medicare_data.csv')
df.head()
# Out:
#                        Brnd_Name             Gnrc_Name  Tot_Mftr  \
# 0       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 1       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 2  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 3  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 4                       Abacavir      Abacavir Sulfate         7
#
#          Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0          Overall     217938.04000      1014318.00000     8595.00000
# 1  Owen Mumford Us     217938.04000      1014318.00000     8595.00000
# 2          Overall     402124.68000      1850703.00000    15403.00000
# 3  Owen Mumford Us     402124.68000      1850703.00000    15403.00000
# 4          Overall   13386250.08000      3189707.00000    48283.00000
#
#    Tot_Benes_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 0      3025.00000                          0.21610               25.35637
# ...

# %%
#taking only 2021 variables
df2021 = df[['Brnd_Name','Gnrc_Name','Tot_Mftr','Mftr_Name','Tot_Spndng_2021', 'Tot_Dsg_Unts_2021', 'Tot_Clms_2021', 'Tot_Benes_2021','Avg_Spnd_Per_Dsg_Unt_Wghtd_2021','Avg_Spnd_Per_Clm_2021','Avg_Spnd_Per_Bene_2021','Chg_Avg_Spnd_Per_Dsg_Unt_20_21','CAGR_Avg_Spnd_Per_Dsg_Unt_17_21']]
df2021.head()
# Out:
#                        Brnd_Name             Gnrc_Name  Tot_Mftr  \
# 0       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 1       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 2  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 3  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 4                       Abacavir      Abacavir Sulfate         7
#
#          Mftr_Name  Tot_Spndng_2021  Tot_Dsg_Unts_2021  Tot_Clms_2021  \
# 0          Overall     102280.76000       459384.00000           3708
# 1  Owen Mumford Us     102280.76000       459384.00000           3708
# 2          Overall     131927.33000       566872.00000           4564
# 3  Owen Mumford Us     131927.33000       566872.00000           4564
# 4          Overall    7038593.83000      2501447.00000          30540
#
#    Tot_Benes_2021  Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  Avg_Spnd_Per_Clm_2021  \
# 0      1313.00000                          0.22300               27.58381
# ...

# %%
df2021 = df2021.sort_values('Tot_Spndng_2021', ascending=True)
df2021 = df2021.round(8)
df2021.tail()
# Out:
#       Brnd_Name     Gnrc_Name  Tot_Mftr        Mftr_Name   Tot_Spndng_2021  \
# 13375   Xarelto   Rivaroxaban         1   Janssen Pharm.  5225547771.90000
# 10875  Revlimid  Lenalidomide         1          Overall  5893547689.00000
# 10876  Revlimid  Lenalidomide         1      Celgene/BMS  5893547689.00000
# 4161    Eliquis      Apixaban         1          Overall 12575145852.00000
# 4162    Eliquis      Apixaban         1  BMS Primarycare 12575145852.00000
#
#        Tot_Dsg_Unts_2021  Tot_Clms_2021  Tot_Benes_2021  \
# 13375    322692140.09000        6458283   1258010.00000
# 10875      7014892.00000         344297     45601.00000
# 10876      7014892.00000         344297     45601.00000
# 4161    1478137928.50000       17015798   3125087.00000
# 4162    1478137928.50000       17015798   3125087.00000
#
#        Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  Avg_Spnd_Per_Clm_2021  \
# 13375                         16.39886              809.12338
# ...

# %%
spending = df['Tot_Spndng_2021']
spending.sum()
# Out:
# 431416682485.57007

# %%
manufacturers = df2021['Mftr_Name'].unique()
index = np.argwhere(manufacturers=='Overall')
manufacturers = np.delete(manufacturers, index)
print(manufacturers)
# Out:
# ['Avpak' 'AHP' 'Bryant Ranch Pr' 'Gsms, Inc.' 'Avkare' 'Kroger Co'
#  'Sancilio & Comp' 'App/Premierpro' 'Equaline Vitami' 'Liberty Pharm'
#  'Pd-Rx Pharm' 'Covidien/Kendal' 'Cypress Pharm.' 'Biomes Pharmace'
#  'Cambridge Senso' 'Accord Healthca' 'Hospira-Novaplu' 'International L'
#  'H2 Pharma LLC' 'Belcher Pharmac' 'Proficient Rx L' 'Quality Care'
#  'Aphena Pharma S' 'Aurobindo Pharm' 'Qualitest/Par P' 'Mckesson Packag'
#  'Cambridge Thera' 'Acella Pharmace' 'Blenheim Pharma' 'One Pharmaceuti'
#  'Alivio Medical' 'Mylan Instituti' 'Fresenius Kabi' 'Pd-Rx Pharm*'
#  'Wal-Mart Stores' "Dr.Reddy'S Lab" 'Hospira/Pfizer' 'Civica, Inc.'
#  'Avet Pharmaceut' 'Hospira/Icu Med' 'Zydus Pharmaceu' 'Major Pharmaceu'
#  'Rite Aid Corp.' 'Hillestad Pharm' 'Bausch Health U' 'Athem, LLC'
#  'Baxter Healthca' 'Physicians Tc.' 'Claris/Baxter' 'Tagi Pharma'
#  'Mylan Inst-Nova' 'Greenstone LLC.' 'Pharm Assoc Inc' 'Sallus Laborato'
# ...

# %%
final_df = pd.DataFrame(columns=['manufacturers', 'Total_Spending'])
for value in manufacturers:
    rows = df2021[df2021['Mftr_Name'] == value]
    total_spending = rows['Tot_Spndng_2021'].sum()
    final_df = final_df.append({'manufacturers': value, 'Total_Spending': total_spending}, ignore_index=True)

print(final_df)
# Out:
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_10248\245812295.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append({'manufacturers': value, 'Total_Spending': total_spending}, ignore_index=True)
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_10248\245812295.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append({'manufacturers': value, 'Total_Spending': total_spending}, ignore_index=True)
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_10248\245812295.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append({'manufacturers': value, 'Total_Spending': total_spending}, ignore_index=True)
# ...

# %%
final_df.head()
# Out:
#      manufacturers  Total_Spending
# 0            Avpak     40127.74000
# 1              AHP   1001054.56000
# 2  Bryant Ranch Pr     41820.85000
# 3       Gsms, Inc.    117393.51000
# 4           Avkare   1742421.45000

# %%
sum_values = final_df['Total_Spending'].sum()

final_df['%_of_total'] = final_df['Total_Spending'] / sum_values
final_df.head(50)
# Out:
#       manufacturers   Total_Spending  %_of_total
# 0             Avpak      40127.74000     0.00000
# 1               AHP    1001054.56000     0.00000
# 2   Bryant Ranch Pr      41820.85000     0.00000
# 3        Gsms, Inc.     117393.51000     0.00000
# 4            Avkare    1742421.45000     0.00001
# 5         Kroger Co        742.58000     0.00000
# 6   Sancilio & Comp       2006.39000     0.00000
# 7    App/Premierpro     607368.76000     0.00000
# 8   Equaline Vitami        117.22000     0.00000
# 9     Liberty Pharm         49.76000     0.00000
# 10      Pd-Rx Pharm      27517.50000     0.00000
# 11  Covidien/Kendal      59922.53000     0.00000
# 12   Cypress Pharm.     442285.56000     0.00000
# 13  Biomes Pharmace     414454.14000     0.00000
# 14  Cambridge Senso         65.36000     0.00000
# 15  Accord Healthca  992557147.29000     0.00460
# 16  Hospira-Novaplu     277146.61000     0.00000
# 17  International L       3610.71000     0.00000
# ...

# %%
spending = final_df['%_of_total']
spending.sum()
# Out:
# 0.9999999999999998
